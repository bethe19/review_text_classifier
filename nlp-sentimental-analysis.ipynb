# %% [markdown]
# ## Natural Language Processing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importing dataset
dataset = pd.read_csv("Restaurant_Reviews.tsv", delimiter = '\t', quoting = 3)

# %% [markdown]
# ## Cleaning the texts

# %%
import re
import nltk

nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

corpus = []
for i in range(1000):
    review = re.sub('[^a-zA-Z]', ' ', dataset['Review'][i]) #replacing non letters by space
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    all_reviews = stopwords.words('english')
    all_reviews.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_reviews)]
    review = (' ').join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bethe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Creating Bag of words Model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
Y = dataset.iloc[:,-1].values

# %% [markdown]
# ## Spliting the Dataset into Training and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X , Y, test_size=0.25, random_state=0)

# %%
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test,y_pred)
cm, accuracy
# Out:
# (array([[ 90,  27],
#         [ 31, 102]], dtype=int64),
#  0.768)
